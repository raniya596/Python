# %%
import pandas as pd

# %%
salary=pd.read_csv("Salaries.csv")
salary
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
salary.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
salary['Notes'].isna().sum()
# Out:
# np.int64(148654)

# %%
del salary['Notes']

# %%
salary
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
salary['Status'].isna().sum()
# Out:
# np.int64(148654)

# %%
del salary['Status']

# %%
salary
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
salary['Benefits'].isna().sum()
# Out:
# np.int64(36163)

# %%
salary["Benefits"].fillna(salary["Benefits"].median(),inplace=True)
# Out:
# C:\Users\fahmi\AppData\Local\Temp\ipykernel_19780\1501266638.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   salary["Benefits"].fillna(salary["Benefits"].median(),inplace=True)

# %%
salary
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
salary["BasePay"].isna().sum()
# Out:
# np.int64(609)

# %%
salary["BasePay"].fillna(salary["BasePay"].mean(),inplace=True)
# Out:
# C:\Users\fahmi\AppData\Local\Temp\ipykernel_19780\1931860124.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   salary["BasePay"].fillna(salary["BasePay"].mean(),inplace=True)

# %%
salary
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18000
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02000
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13000
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00000
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60000
# ...                                                ...           ...
# ...

# %%
del salary["Agency"]

# %%
salary
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18000
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02000
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13000
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00000
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60000
# ...                                                ...           ...
# ...

# %%
salary["OtherPay"].isna().sum()
# Out:
# np.int64(4)

# %%
salary["OvertimePay"].isna().sum()
# Out:
# np.int64(4)

# %%
salary["JobTitle"].value_counts()
# Out:
# JobTitle
# Transit Operator                      7036
# Special Nurse                         4389
# Registered Nurse                      3736
# Public Svc Aide-Public Works          2518
# Police Officer 3                      2421
#                                       ...
# Light Rail Vehicle Equip Eng             1
# Civil Case Settlmnt Specialist           1
# ADMINISTRATOR, SFGH MEDICAL CENTER       1
# CHIEF OF POLICE                          1
# Special Assistant 8                      1
# Name: count, Length: 2159, dtype: int64

# %%
salary["EmployeeName"].value_counts()
# Out:
# EmployeeName
# Kevin Lee                 13
# William Wong              11
# Richard Lee               11
# Steven Lee                11
# John Chan                  9
#                           ..
# Saoirse C Brownfield       1
# Miguel P Lucana            1
# Johnmark L Henderson       1
# Laura R Epstein-Norris     1
# Kesha Mcwhorter            1
# Name: count, Length: 110811, dtype: int64

# %%
salary[salary["EmployeeName"]=="Kevin Lee"]
# Out:
#             Id EmployeeName                        JobTitle    BasePay  \
# 39715    39716    Kevin Lee                Police Officer 3  115866.90
# 40570    40571    Kevin Lee                Police Officer 3  117171.41
# 42510    42511    Kevin Lee  Electrical Transit System Mech   79220.54
# 49270    49271    Kevin Lee          Deputy Court Clerk III   84512.32
# 49439    49440    Kevin Lee          Deputy Court Clerk III   84512.34
# 50123    50124    Kevin Lee               Personnel Analyst   83382.00
# 52233    52234    Kevin Lee  Senior Parking Control Officer   66774.03
# 53931    53932    Kevin Lee                Transit Operator   57397.32
# 55119    55120    Kevin Lee              IS Administrator 2   68940.44
# 112385  112386    Kevin Lee                      Sergeant 3  137982.14
# 123141  123142    Kevin Lee  IT Operations Support Admin IV   91606.03
# 124165  124166    Kevin Lee               Personnel Analyst   88353.01
# ...

# %%
salary[salary["EmployeeName"]=="Kevin Lee"]["BasePay"].max()
# Out:
# 137982.14

# %%
salary[salary["EmployeeName"]=="Kevin Lee"]["BasePay"].min()
# Out:
# 57397.32

# %%
salary[salary["EmployeeName"]=="Kevin Lee"][["OvertimePay","OtherPay","Benefits","TotalPay","TotalPayBenefits"]].max()
# Out:
# OvertimePay          40247.39
# OtherPay             16039.62
# Benefits             43039.12
# TotalPay            172558.95
# TotalPayBenefits    215598.07
# dtype: float64

# %%
salary[salary["OvertimePay"]==40247.39][["EmployeeName","TotalPayBenefits"]]
# Out:
#       EmployeeName  TotalPayBenefits
# 42510    Kevin Lee         161602.46

# %%
salary[salary["Year"]==2011][["EmployeeName","TotalPayBenefits"]]
# Out:
#              EmployeeName  TotalPayBenefits
# 0          NATHANIEL FORD         567595.43
# 1            GARY JIMENEZ         538909.28
# 2          ALBERT PARDINI         335279.91
# 3       CHRISTOPHER CHONG         332343.61
# 4         PATRICK GARDNER         326373.19
# ...                   ...               ...
# 36154       SERENA HUGHES              4.17
# 36155        JOE BROWN JR              0.30
# 36156      PAULETTE ADAMS              0.00
# 36157       KAUKAB MOHSIN              0.00
# 36158  JOSEPHINE MCCREARY              0.00
#
# [36159 rows x 2 columns]

# %%
salary[salary["JobTitle"]=="CAPTAIN III (POLICE DEPARTMENT)"]
# Out:
#           Id       EmployeeName                         JobTitle    BasePay  \
# 1          2       GARY JIMENEZ  CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2          3     ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 11        12   PATRICIA JACKSON  CAPTAIN III (POLICE DEPARTMENT)   99722.00
# 61        62         ANNA BROWN  CAPTAIN III (POLICE DEPARTMENT)  102571.24
# 65        66      RICHARD PARRY  CAPTAIN III (POLICE DEPARTMENT)  185369.69
# 91        92      DONNA MEIXNER  CAPTAIN III (POLICE DEPARTMENT)  102722.40
# 93        94        JOHN MURPHY  CAPTAIN III (POLICE DEPARTMENT)  215914.03
# 125      126    SHARON FERRIGNO  CAPTAIN III (POLICE DEPARTMENT)  185369.68
# 211      212     CROCE CASCIATO  CAPTAIN III (POLICE DEPARTMENT)  188341.62
# 214      215        JOHN FEENEY  CAPTAIN III (POLICE DEPARTMENT)  188348.55
# 225      226   STEPHEN TACCHINI  CAPTAIN III (POLICE DEPARTMENT)  188341.60
# ...

# %%
salary[salary["JobTitle"]=="CAPTAIN III (POLICE DEPARTMENT)"]
# Out:
#           Id       EmployeeName                         JobTitle    BasePay  \
# 1          2       GARY JIMENEZ  CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2          3     ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 11        12   PATRICIA JACKSON  CAPTAIN III (POLICE DEPARTMENT)   99722.00
# 61        62         ANNA BROWN  CAPTAIN III (POLICE DEPARTMENT)  102571.24
# 65        66      RICHARD PARRY  CAPTAIN III (POLICE DEPARTMENT)  185369.69
# 91        92      DONNA MEIXNER  CAPTAIN III (POLICE DEPARTMENT)  102722.40
# 93        94        JOHN MURPHY  CAPTAIN III (POLICE DEPARTMENT)  215914.03
# 125      126    SHARON FERRIGNO  CAPTAIN III (POLICE DEPARTMENT)  185369.68
# 211      212     CROCE CASCIATO  CAPTAIN III (POLICE DEPARTMENT)  188341.62
# 214      215        JOHN FEENEY  CAPTAIN III (POLICE DEPARTMENT)  188348.55
# 225      226   STEPHEN TACCHINI  CAPTAIN III (POLICE DEPARTMENT)  188341.60
# ...

# %%
salary[salary["EmployeeName"]=="Kevin Lee"][["OvertimePay","OtherPay","Benefits","TotalPay","TotalPayBenefits"]].min()
# Out:
# OvertimePay             0.00
# OtherPay                0.00
# Benefits            30650.48
# TotalPay            68940.44
# TotalPayBenefits    99590.92
# dtype: float64

# %%
salary[salary["EmployeeName"]=="Kevin Lee"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, 39715 to 124658
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                13 non-null     int64
#  1   EmployeeName      13 non-null     object
#  2   JobTitle          13 non-null     object
#  3   BasePay           13 non-null     float64
#  4   OvertimePay       13 non-null     float64
#  5   OtherPay          13 non-null     float64
#  6   Benefits          13 non-null     float64
#  7   TotalPay          13 non-null     float64
#  8   TotalPayBenefits  13 non-null     float64
#  9   Year              13 non-null     int64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 1.1+ KB

# %%
salary[salary["EmployeeName"]=="Kevin Lee"].describe()
# Out:
#                   Id        BasePay   OvertimePay      OtherPay      Benefits  \
# count      13.000000      13.000000     13.000000     13.000000     13.000000
# mean    70559.384615   87919.136923  10189.609231   3334.917692  35363.041538
# std     35496.076270   23171.890796  12461.866739   4597.809037   3100.834288
# min     39716.000000   57397.320000      0.000000      0.000000  30650.480000
# 25%     49271.000000   68940.440000      0.000000    975.440000  34109.610000
# 50%     52234.000000   84512.320000   9599.080000   1469.990000  34906.200000
# 75%    112386.000000   91606.030000  18537.190000   4050.850000  36080.300000
# max    124659.000000  137982.140000  40247.390000  16039.620000  43039.120000
#
#             TotalPay  TotalPayBenefits         Year
# count      13.000000         13.000000    13.000000
# mean   101443.663846     136806.705385  2012.615385
# std     33446.591717      35577.215138     0.960769
# min     68940.440000      99590.920000  2012.000000
# ...

# %%
salary[salary["EmployeeName"]=="William Wong"]
# Out:
#             Id  EmployeeName                        JobTitle    BasePay  \
# 38490    38491  William Wong                     Firefighter  110847.11
# 40670    40671  William Wong  Electrical Transit System Mech   79221.70
# 42745    42746  William Wong                     Manager III  111335.82
# 50252    50253  William Wong       EMT/Paramedic/Firefighter   83216.52
# 50978    50979  William Wong    Stationary Eng, Sewage Plant   74701.80
# 51096    51097  William Wong    Automotive Body & Fender Wrk   74682.66
# 63486    63487  William Wong       Automotive Service Worker   25132.60
# 118418  118419  William Wong  Electrical Transit System Mech   81830.00
# 121990  121991  William Wong  Electrical Transit System Mech   80568.00
# 123792  123793  William Wong       EMT/Paramedic/Firefighter   84656.00
# 125560  125561  William Wong    Automotive Body & Fender Wrk   78672.03
#
#         OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# ...

# %%
salary[salary["EmployeeName"]=="William Wong"][["BasePay","OvertimePay","OtherPay","Benefits","TotalPay","TotalPayBenefits","Year"]].max()
# Out:
# BasePay             111335.82
# OvertimePay          48610.36
# OtherPay             18127.17
# Benefits             45624.73
# TotalPay            159980.68
# TotalPayBenefits    199273.62
# Year                  2014.00
# dtype: float64

# %%
salary[salary["EmployeeName"]=="William Wong"][["BasePay","OvertimePay","OtherPay","Benefits","TotalPay","TotalPayBenefits","Year"]].min()
# Out:
# BasePay             25132.60
# OvertimePay             0.00
# OtherPay              366.32
# Benefits            14284.35
# TotalPay            40971.47
# TotalPayBenefits    55255.82
# Year                 2012.00
# dtype: float64

# %%
salary[salary["EmployeeName"]=="William Wong"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 38490 to 125560
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                11 non-null     int64
#  1   EmployeeName      11 non-null     object
#  2   JobTitle          11 non-null     object
#  3   BasePay           11 non-null     float64
#  4   OvertimePay       11 non-null     float64
#  5   OtherPay          11 non-null     float64
#  6   Benefits          11 non-null     float64
#  7   TotalPay          11 non-null     float64
#  8   TotalPayBenefits  11 non-null     float64
#  9   Year              11 non-null     int64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 968.0+ bytes

# %%
salary[salary["EmployeeName"]=="William Wong"].describe()
# Out:
#                   Id        BasePay   OvertimePay      OtherPay      Benefits  \
# count      11.000000      11.000000     11.000000     11.000000     11.000000
# mean    75226.181818   80442.203636  14342.491818   5039.560000  32898.850909
# std     38046.031774   22441.409387  15402.087751   5533.162439   7835.076954
# min     38491.000000   25132.600000      0.000000    366.320000  14284.350000
# 25%     46499.500000   76686.915000   4980.105000    767.625000  31358.930000
# 50%     51097.000000   80568.000000   6985.790000   2957.450000  32825.300000
# 75%    120205.000000   83936.260000  23104.205000   7699.415000  36459.370000
# max    125561.000000  111335.820000  48610.360000  18127.170000  45624.730000
#
#             TotalPay  TotalPayBenefits         Year
# count      11.000000         11.000000    11.000000
# mean    99824.255455     132723.106364  2012.727273
# std     31718.899567      38260.542054     1.009050
# min     40971.470000      55255.820000  2012.000000
# ...

# %%
salary
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18000
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02000
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13000
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00000
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60000
# ...                                                ...           ...
# ...

# %%
salary.groupby("EmployeeName")["BasePay"].mean()
# Out:
# EmployeeName
# A BERNARD FATOOH         19969.370
# A Bernard  Fatooh        23908.500
# A Bernard Fatooh         21266.850
# A ELIZABETH MARCHASIN    23591.800
# A JAMIL NIAZI            69058.190
#                            ...
# Zun Jin Zhang He         52612.505
# Zuna Luu                 51502.860
# Zuna T Luu               54864.500
# Zuri  Jones              71986.900
# Zuri Jones               76628.030
# Name: BasePay, Length: 110811, dtype: float64

# %%
salary.groupby(["EmployeeName","JobTitle","Year"])[["BasePay","TotalPay","OtherPay","OvertimePay"]].mean()
# Out:
#                                                        BasePay  TotalPay  \
# EmployeeName          JobTitle                  Year
# A BERNARD FATOOH      SHERIFF'S PROPERTY KEEPER 2011  19969.37  20039.91
# A Bernard  Fatooh     Sheriff's Property Keeper 2013  23908.50  23923.62
# A Bernard Fatooh      Sheriff's Property Keeper 2012  18472.35  18500.19
#                                                 2014  24061.35  24061.35
# A ELIZABETH MARCHASIN PRINCIPAL CLERK           2011  23591.80  26282.86
# ...                                                        ...       ...
# Zuna T Luu            Custodian                 2013  55026.00  56155.44
#                                                 2014  54703.00  56087.91
# Zuri  Jones           Deputy Probation Officer  2013  71986.90  71986.90
# Zuri Jones            Deputy Probation Officer  2012  86588.52  86588.52
#                                                 2014  66667.54  66667.54
#
# ...

# %%
salary.groupby(["EmployeeName","JobTitle","Year"])[["BasePay","TotalPay","OtherPay","OvertimePay"]].sum()
# Out:
#                                                        BasePay  TotalPay  \
# EmployeeName          JobTitle                  Year
# A BERNARD FATOOH      SHERIFF'S PROPERTY KEEPER 2011  19969.37  20039.91
# A Bernard  Fatooh     Sheriff's Property Keeper 2013  23908.50  23923.62
# A Bernard Fatooh      Sheriff's Property Keeper 2012  18472.35  18500.19
#                                                 2014  24061.35  24061.35
# A ELIZABETH MARCHASIN PRINCIPAL CLERK           2011  23591.80  26282.86
# ...                                                        ...       ...
# Zuna T Luu            Custodian                 2013  55026.00  56155.44
#                                                 2014  54703.00  56087.91
# Zuri  Jones           Deputy Probation Officer  2013  71986.90  71986.90
# Zuri Jones            Deputy Probation Officer  2012  86588.52  86588.52
#                                                 2014  66667.54  66667.54
#
# ...

# %%
salary
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18000
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02000
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13000
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00000
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60000
# ...                                                ...           ...
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
plt.plot(salary["Year"],salary["BasePay"])
plt.show()

# %%
plt.plot(salary["Year"],salary["Benefits"])
plt.show()

# %%
plt.plot(salary["Year"],salary["TotalPayBenefits"])
plt.show()

# %%
plt.plot(salary["Year"],salary["TotalPay"])
plt.show()

# %%
plt.scatter(salary["BasePay"],salary["TotalPay"])
plt.show()

# %%
c=salary.head()

# %%
c
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25  28628.62  567595.43         567595.43
# 1  155966.02    245131.88  137811.38  28628.62  538909.28         538909.28
# 2  212739.13    106088.18   16452.60  28628.62  335279.91         335279.91
# 3   77916.00     56120.71  198306.90  28628.62  332343.61         332343.61
# 4  134401.60      9737.00  182234.59  28628.62  326373.19         326373.19
#
#    Year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
p=salary.groupby("JobTitle")["TotalPay"].sum().sort_values(ascending =False).head()

# %%
p
# Out:
# JobTitle
# Transit Operator    4.553076e+08
# Registered Nurse    4.322574e+08
# Firefighter         3.441351e+08
# Police Officer 3    3.266096e+08
# Deputy Sheriff      2.120763e+08
# Name: TotalPay, dtype: float64

# %%
myexplode=(0.2,0.5,0,0,0)
p.plot.pie(autopct="%1.1f%%")
# Out:
# <Axes: ylabel='TotalPay'>

# %%
myexplode=(0.2,0.5,0,0,0)
p.plot.pie(autopct="%1.1f%%",explode=myexplode)
# Out:
# <Axes: ylabel='TotalPay'>

# %%
plt.bar(salary["Benefits"],salary["TotalPayBenefits"],1.0)
plt.show()

# %%
plt.barh(salary["Benefits"],salary["TotalPayBenefits"])
plt.show()

# %% [markdown]
# # seaborn

# %%
import seaborn as sns

# %%
sns.histplot(x="TotalPay",bins=30,data=salary,color="red",kde=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sns.histplot(x="TotalPay",bins=30,data=salary,color="red",kde=True)
#
# NameError: name 'salary' is not defined

# %%
salary.columns

# %%
corr=salary[['BasePay','TotalPay','TotalPayBenefits']].corr()

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
salary.corr(numeric_only=True)
# Out:
#                         Id   BasePay  OvertimePay  OtherPay  Benefits  \
# Id                1.000000 -0.204628    -0.081505 -0.100403 -0.313756
# BasePay          -0.204628  1.000000     0.266633  0.283760  0.797121
# OvertimePay      -0.081505  0.266633     1.000000  0.316592  0.263702
# OtherPay         -0.100403  0.283760     0.316592  1.000000  0.202009
# Benefits         -0.313756  0.797121     0.263702  0.202009  1.000000
# TotalPay         -0.211478  0.950514     0.504859  0.470496  0.773559
# TotalPayBenefits -0.092190  0.942999     0.467981  0.422341  0.814595
# Year              0.968171  0.033737     0.027887 -0.002499 -0.116167
#
#                   TotalPay  TotalPayBenefits      Year
# Id               -0.211478         -0.092190  0.968171
# BasePay           0.950514          0.942999  0.033737
# OvertimePay       0.504859          0.467981  0.027887
# OtherPay          0.470496          0.422341 -0.002499
# Benefits          0.773559          0.814595 -0.116167
# ...

# %%
corr=salary.corr(numeric_only=True)

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.barplot(x="year",y="TotalPay",data=salary,color="red",estimator=sum)
plt.title("sum of totalpay by year")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.barplot(x="year",y="TotalPay",data=salary,color="red",estimator=sum)
#       2 plt.title("sum of totalpay by year")
#       3 plt.show()
#
# NameError: name 'sns' is not defined
